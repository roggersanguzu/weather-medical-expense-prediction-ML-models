# %%
import pandas as pd
import numpy as np

# %%
football=pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')
football
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %%
football[football['HomeTeam']=='Newcastle']
# Out:
#     Div        Date   Time   HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 4    E0  17/08/2024  15:00  Newcastle     Southampton     1     0   H     1
# 28   E0  01/09/2024  13:30  Newcastle       Tottenham     2     1   H     1
# 50   E0  28/09/2024  12:30  Newcastle        Man City     1     1   D     0
# 74   E0  19/10/2024  15:00  Newcastle        Brighton     0     1   A     0
# 90   E0  02/11/2024  12:30  Newcastle         Arsenal     1     0   H     1
# 119  E0  25/11/2024  20:00  Newcastle        West Ham     0     2   A     0
# 134  E0  04/12/2024  19:30  Newcastle       Liverpool     3     3   D     1
# 151  E0  14/12/2024  15:00  Newcastle       Leicester     4     0   H     1
# 172  E0  26/12/2024  15:00  Newcastle     Aston Villa     3     0   H     1
# 205  E0  15/01/2025  19:30  Newcastle          Wolves     3     0   H     1
# 209  E0  18/01/2025  12:30  Newcastle     Bournemouth     1     4   A     1
# ...

# %%
football[football['HomeTeam']=='Newcastle'].value_counts('HomeTeam')
# Out:
# HomeTeam
# Newcastle    19
# Name: count, dtype: int64

# %%
football[football['AwayTeam']=='Man United'].value_counts('AwayTeam')
# Out:
# AwayTeam
# Man United    19
# Name: count, dtype: int64

# %%
football[football['HomeTeam']!='Chelsea']
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %%
football[football['AwayTeam']!='Man United'].value_counts('AwayTeam')
# Out:
# AwayTeam
# Arsenal           19
# Leicester         19
# West Ham          19
# Tottenham         19
# Southampton       19
# Nott'm Forest     19
# Newcastle         19
# Man City          19
# Liverpool         19
# Ipswich           19
# Aston Villa       19
# Fulham            19
# Everton           19
# Crystal Palace    19
# Chelsea           19
# Brighton          19
# Brentford         19
# Bournemouth       19
# Wolves            19
# Name: count, dtype: int64

# %%
football[football['Date']=='17/08/2024'].value_counts('Date')
# Out:
# Date
# 17/08/2024    6
# Name: count, dtype: int64

# %%
football[football['Date']=='17/08/2024']
# Out:
#   Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 1  E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2  E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3  E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4  E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# 5  E0  17/08/2024  15:00  Nott'm Forest  Bournemouth     1     1   D     1
# 6  E0  17/08/2024  17:30       West Ham  Aston Villa     1     2   A     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 1     0  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99
# 2     0  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99
# 3     1  ...     1.87     2.06   1.86   2.07     1.92     2.10     1.83
# 4     0  ...     1.87     2.06   1.88   2.06     1.89     2.10     1.82
# 5     0  ...     1.94     1.99   1.94   1.98     2.05     2.00     1.93
# ...

# %%
football[(football['Date']=='17/08/2024') & (football['B365CAHA']<=2.05)]
# Out:
#   Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 1  E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2  E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 5  E0  17/08/2024  15:00  Nott'm Forest  Bournemouth     1     1   D     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 1     0  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99
# 2     0  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99
# 5     0  ...     1.94     1.99   1.94   1.98     2.05     2.00     1.93
#
#    AvgCAHA  BFECAHH  BFECAHA
# 1     1.88     2.04     1.93
# 2     1.87     2.02     1.96
# 5     1.93     1.96     2.02
#
# [3 rows x 120 columns]

# %%
np.where(football['PCAHA']>1.5,'High','Low')
# Out:
# array(['High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
# ...

# %%
football['Analysis']=np.where(football['B365CAHA']>=2.0,'High','Low')

# %%
football.head(20)
# Out:
#    Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0   E0  16/08/2024  20:00      Man United          Fulham     1     0   H
# 1   E0  17/08/2024  12:30         Ipswich       Liverpool     0     2   A
# 2   E0  17/08/2024  15:00         Arsenal          Wolves     2     0   H
# 3   E0  17/08/2024  15:00         Everton        Brighton     0     3   A
# 4   E0  17/08/2024  15:00       Newcastle     Southampton     1     0   H
# 5   E0  17/08/2024  15:00   Nott'm Forest     Bournemouth     1     1   D
# 6   E0  17/08/2024  17:30        West Ham     Aston Villa     1     2   A
# 7   E0  18/08/2024  14:00       Brentford  Crystal Palace     2     1   H
# 8   E0  18/08/2024  16:30         Chelsea        Man City     0     2   A
# 9   E0  19/08/2024  20:00       Leicester       Tottenham     1     1   D
# 10  E0  24/08/2024  12:30        Brighton      Man United     2     1   H
# 11  E0  24/08/2024  15:00  Crystal Palace        West Ham     0     2   A
# ...

# %%
np.where(football['PCAHH']>=2,"High","Low")
# Out:
# array(['Low', 'High', 'High', 'Low', 'Low', 'Low', 'Low', 'High', 'Low',
#        'High', 'High', 'Low', 'Low', 'Low', 'High', 'High', 'Low', 'Low',
#        'Low', 'High', 'High', 'High', 'Low', 'Low', 'High', 'High', 'Low',
#        'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'Low', 'High',
#        'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low',
#        'High', 'High', 'Low', 'High', 'High', 'High', 'Low', 'Low',
#        'High', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'High', 'Low',
#        'High', 'Low', 'High', 'Low', 'Low', 'Low', 'High', 'Low', 'Low',
#        'High', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High',
#        'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'High', 'Low', 'High',
#        'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'High', 'High',
#        'High', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'Low',
#        'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'Low',
# ...

# %%
football['Final']=np.where(football['PCAHH']>=2,"High","Low")

# %%
football.head(50)
# Out:
#    Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0   E0  16/08/2024  20:00      Man United          Fulham     1     0   H
# 1   E0  17/08/2024  12:30         Ipswich       Liverpool     0     2   A
# 2   E0  17/08/2024  15:00         Arsenal          Wolves     2     0   H
# 3   E0  17/08/2024  15:00         Everton        Brighton     0     3   A
# 4   E0  17/08/2024  15:00       Newcastle     Southampton     1     0   H
# 5   E0  17/08/2024  15:00   Nott'm Forest     Bournemouth     1     1   D
# 6   E0  17/08/2024  17:30        West Ham     Aston Villa     1     2   A
# 7   E0  18/08/2024  14:00       Brentford  Crystal Palace     2     1   H
# 8   E0  18/08/2024  16:30         Chelsea        Man City     0     2   A
# 9   E0  19/08/2024  20:00       Leicester       Tottenham     1     1   D
# 10  E0  24/08/2024  12:30        Brighton      Man United     2     1   H
# 11  E0  24/08/2024  15:00  Crystal Palace        West Ham     0     2   A
# ...

# %%
condition=[
football['PCAHH']>=3.0,
(football['PCAHH']>2.0) & (football['PCAHH']<3.0),
(football['PCAHH']>=1.5)  & (football['PCAHH']<2.0),
(football['PCAHH']>=1.0)  & (football['PCAHH']<1.5)
]
values=['Best','Worse','Worst','Worwest']

# %%
football['Trial']=np.select(condition,values)

# %%
football.head(5)
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... PCAHA MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  BFECAHH  BFECAHA  Analysis  \
# 0  ...  2.11    1.88     2.11     1.82     2.05     1.90     2.08      High
# 1  ...  1.90    2.20     2.00     1.99     1.88     2.04     1.93       Low
# 2  ...  1.90    2.05     1.93     1.99     1.87     2.02     1.96       Low
# 3  ...  2.07    1.92     2.10     1.83     2.04     1.88     2.11      High
# 4  ...  2.06    1.89     2.10     1.82     2.05     1.89     2.10      High
#
#    Final  Trial
# 0    Low  Worst
# ...

# %%
football['Trial'].value_counts()
# Out:
# Trial
# Worst    251
# Worse    115
# 0         14
# Name: count, dtype: int64

# %%
football[(football['HomeTeam'].isin(['Everton','Newcastle'])) | (football['HomeTeam'].isin(['Man United','Arsenal']))]
# Out:
#     Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0
# 2    E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1
# 20   E0  31/08/2024  12:30     Arsenal     Brighton     1     1   D     1
# ..   ..         ...    ...         ...          ...   ...   ...  ..   ...
# 356  E0  11/05/2025  14:15  Man United     West Ham     0     2   A     0
# 362  E0  18/05/2025  12:00     Everton  Southampton     2     0   H     2
# 366  E0  18/05/2025  16:30     Arsenal    Newcastle     1     0   H     0
# 374  E0  25/05/2025  16:00  Man United  Aston Villa     2     0   H     0
# 375  E0  25/05/2025  16:00   Newcastle      Everton     0     1   A     0
#
#      HTAG  ... PCAHA MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  BFECAHH  BFECAHA  \
# ...

# %%
football[football.duplicated('BFECAHA')]
# Out:
#     Div        Date   Time       HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  \
# 9    E0  19/08/2024  20:00      Leicester  Tottenham     1     1   D     0
# 15   E0  24/08/2024  15:00      Tottenham    Everton     4     0   H     2
# 18   E0  25/08/2024  14:00         Wolves    Chelsea     2     6   A     2
# 19   E0  25/08/2024  16:30      Liverpool  Brentford     2     0   H     1
# 23   E0  31/08/2024  15:00        Ipswich     Fulham     1     1   D     1
# ..   ..         ...    ...            ...        ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle    Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest    Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton    Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham   Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves  Brentford     1     1   D     0
#
# ...

# %%
football[football.duplicated(['BFECAHA','AvgCAHH','PCAHA'])]
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 57   E0  29/09/2024  14:00         Ipswich     Aston Villa     2     2   D
# 74   E0  19/10/2024  15:00       Newcastle        Brighton     0     1   A
# 76   E0  19/10/2024  17:30     Bournemouth         Arsenal     2     0   H
# 121  E0  30/11/2024  15:00       Brentford       Leicester     4     1   H
# 122  E0  30/11/2024  15:00  Crystal Palace       Newcastle     1     1   D
# 123  E0  30/11/2024  15:00   Nott'm Forest         Ipswich     1     0   H
# 139  E0  05/12/2024  20:15     Bournemouth       Tottenham     1     0   H
# 154  E0  15/12/2024  14:00        Brighton  Crystal Palace     1     3   A
# 178  E0  27/12/2024  20:15         Arsenal         Ipswich     1     0   H
# 181  E0  29/12/2024  15:00         Everton   Nott'm Forest     0     2   A
# 191  E0  04/01/2025  15:00     Bournemouth         Everton     1     0   H
# ...

# %%
football2=pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E2.csv')
football2
# Out:
#     Div        Date   Time      HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E2  09/08/2024  20:00      Barnsley     Mansfield     1     2   A     1
# 1    E2  10/08/2024  17:30    Birmingham       Reading     1     1   D     0
# 2    E2  10/08/2024  17:30   Bristol Rvs   Northampton     1     0   H     0
# 3    E2  10/08/2024  17:30        Burton       Lincoln     2     3   A     2
# 4    E2  10/08/2024  17:30  Crawley Town     Blackpool     2     1   H     2
# ..   ..         ...    ...           ...           ...   ...   ...  ..   ...
# 547  E2  03/05/2025  15:00   Northampton         Wigan     1     1   D     1
# 548  E2  03/05/2025  15:00       Reading      Barnsley     2     4   A     0
# 549  E2  03/05/2025  15:00     Rotherham     Peterboro     2     1   H     1
# 550  E2  03/05/2025  15:00    Shrewsbury  Crawley Town     1     2   A     0
# 551  E2  03/05/2025  15:00       Wycombe     Stockport     1     3   A     1
#
# ...

# %%
football2['B365CAHA'].apply(np.sqrt)
# Out:
# 0      1.352775
# 1      1.431782
# 2      1.371131
# 3      1.431782
# 4      1.424781
#          ...
# 547    1.341641
# 548    1.414214
# 549    1.389244
# 550    1.352775
# 551    1.414214
# Name: B365CAHA, Length: 552, dtype: float64

# %%
football2['B365CAHA'].apply(np.sum)
# Out:
# 0      1.83
# 1      2.05
# 2      1.88
# 3      2.05
# 4      2.03
#        ...
# 547    1.80
# 548    2.00
# 549    1.93
# 550    1.83
# 551    2.00
# Name: B365CAHA, Length: 552, dtype: float64

# %%
football2['B365CAHA'].apply(np.mean)
# Out:
# 0      1.83
# 1      2.05
# 2      1.88
# 3      2.05
# 4      2.03
#        ...
# 547    1.80
# 548    2.00
# 549    1.93
# 550    1.83
# 551    2.00
# Name: B365CAHA, Length: 552, dtype: float64

# %%
football2.pivot(index="Date",columns="HomeTeam",values="B365CAHH")
# Out:
# HomeTeam    Barnsley  Birmingham  Blackpool  Bolton  Bristol Rvs  Burton  \
# Date
# 01/01/2025      1.75         NaN       2.00     NaN         1.98    1.93
# 01/02/2025      1.88        2.00       2.05     NaN          NaN     NaN
# 01/03/2025      1.93        2.10        NaN     NaN         1.93    2.03
# 01/04/2025      1.98         NaN       1.75     NaN         1.95    1.90
# 01/10/2024      1.93        1.75       1.98     NaN         2.00     NaN
# ...              ...         ...        ...     ...          ...     ...
# 29/04/2025       NaN         NaN        NaN     NaN          NaN    2.00
# 29/10/2024       NaN         NaN        NaN     NaN          NaN     NaN
# 29/12/2024       NaN        1.88        NaN    1.95          NaN     NaN
# 30/04/2025       NaN         NaN       1.98     NaN          NaN     NaN
# 31/08/2024       NaN        1.95       1.80    1.73         1.80     NaN
#
# HomeTeam    Cambridge  Charlton  Crawley Town  Exeter  ...  Northampton  \
# ...

# %%
netflix=pd.read_excel('NetflixDataset.xlsx')
netflix
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date  \
# 0           2           Premium         15000000      44444
# 1           6           Premium         15000000      44638
# 2          10           Premium         15000000      44933
# 3          12           Premium         15000000      45008
# 4          16           Premium         15000000      44658
# ...       ...               ...              ...        ...
# 2495     2474           Premium         10000000      44810
# 2496     2478          Standard         10000000      44789
# 2497     2481           Premium         10000000      44778
# 2498     2486             Basic         10000000      44767
# 2499     2490          Standard         10000000      44759
#
#       Last Payment Date        Country  Age  Gender      Device Plan Duration
# 0                 45099         Canada   35  Female      Tablet       1 Month
# 1                 45104         France   29  Female    Smart TV       1 Month
# ...

# %%
netflix[netflix.duplicated('User ID')]
# Out:
# Empty DataFrame
# Columns: [User ID, Subscription Type, Monthly Revenue, Join Date, Last Payment Date, Country, Age, Gender, Device, Plan Duration]
# Index: []

# %%
netflix.pivot(index="User ID",columns="Subscription Type",values="Last Payment Date")
# Out:
# Subscription Type    Basic  Premium  Standard
# User ID
# 1                  45087.0      NaN       NaN
# 2                      NaN  45099.0       NaN
# 3                      NaN      NaN   45104.0
# 4                      NaN      NaN   45103.0
# 5                  45105.0      NaN       NaN
# ...                    ...      ...       ...
# 2496                   NaN  45119.0       NaN
# 2497               45121.0      NaN       NaN
# 2498                   NaN      NaN   45122.0
# 2499                   NaN      NaN   45119.0
# 2500               45119.0      NaN       NaN
#
# [2500 rows x 3 columns]

# %%
netflix.plot(kind='line',xlabel="Gender",ylabel="Subscription Type",title="NETFLIX USER DATA",figsize=(10,5))
# Out:
# <Axes: title={'center': 'NETFLIX USER DATA'}, xlabel='Gender', ylabel='Subscription Type'>
