# %%
import pandas as pd
import numpy as np

# %%
netflix=pd.read_excel('NetflixDataset.xlsx')
netflix
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date  \
# 0           2           Premium         15000000      44444
# 1           6           Premium         15000000      44638
# 2          10           Premium         15000000      44933
# 3          12           Premium         15000000      45008
# 4          16           Premium         15000000      44658
# ...       ...               ...              ...        ...
# 2495     2474           Premium         10000000      44810
# 2496     2478          Standard         10000000      44789
# 2497     2481           Premium         10000000      44778
# 2498     2486             Basic         10000000      44767
# 2499     2490          Standard         10000000      44759
#
#       Last Payment Date        Country  Age  Gender      Device Plan Duration
# 0                 45099         Canada   35  Female      Tablet       1 Month
# 1                 45104         France   29  Female    Smart TV       1 Month
# ...

# %%
x=netflix.plot(kind='line',xlabel='Monthly Revenue',ylabel='country',title='Netflix User Data',figsize=(10,5))

# %%
x=netflix.plot(kind='bar',xlabel='Monthly Revenue',ylabel='country',title='Netflix User Data',figsize=(10,5))
